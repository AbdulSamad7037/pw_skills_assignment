# %% [markdown]
# 1.Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %% [markdown]
# Step 1: Calculate
# 𝑇
# (
# 1
# )
# T(1)
# Using the given recurrence relation:
#
# 𝑇
# (
# 1
# )
# =
# 3
# 𝑇
# (
# 0
# )
# +
# 12
# ×
# 1
# T(1)=3T(0)+12×1
# Substituting
# 𝑇
# (
# 0
# )
# =
# 5
# T(0)=5:
#
# 𝑇
# (
# 1
# )
# =
# 3
# ×
# 5
# +
# 12
# =
# 15
# +
# 12
# =
# 27
# T(1)=3×5+12=15+12=27
# Step 2: Calculate
# 𝑇
# (
# 2
# )
# T(2)
# Now, use the recurrence relation again to find
# 𝑇
# (
# 2
# )
# T(2):
#
# 𝑇
# (
# 2
# )
# =
# 3
# 𝑇
# (
# 1
# )
# +
# 12
# ×
# 2
# T(2)=3T(1)+12×2
# Substituting
# 𝑇
# (
# 1
# )
# =
# 27
# T(1)=27:
#
# 𝑇
# (
# 2
# )
# =
# 3
# ×
# 27
# +
# 24
# =
# 81
# +
# 24
# =
# 105
# T(2)=3×27+24=81+24=105
# So, the value of
# 𝑇
# (
# 2
# )
# T(2) is
# 105
# 105
# ​
#  .

# %% [markdown]
# ## Explanation

# %% [markdown]
# The Recurrence Relation
# You are given the recurrence relation:
#
# 𝑇
# (
# 𝑛
# )
# =
# 3
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 12
# 𝑛
# T(n)=3T(n−1)+12n
# This equation tells us how to calculate
# 𝑇
# (
# 𝑛
# )
# T(n) based on the value of
# 𝑇
# (
# 𝑛
# −
# 1
# )
# T(n−1), with an additional term
# 12
# 𝑛
# 12n.
#
# Initial Condition
# You are also given an initial condition, which is:
#
# 𝑇
# (
# 0
# )
# =
# 5
# T(0)=5
# This is the base case, the starting point from which we can calculate the subsequent values of
# 𝑇
# (
# 𝑛
# )
# T(n).
#
# Step-by-Step Calculation
# Step 1: Calculate
# 𝑇
# (
# 1
# )
# T(1)
# To find
# 𝑇
# (
# 1
# )
# T(1), we use the recurrence relation with
# 𝑛
# =
# 1
# n=1:
#
# 𝑇
# (
# 1
# )
# =
# 3
# 𝑇
# (
# 0
# )
# +
# 12
# ×
# 1
# T(1)=3T(0)+12×1
# Here,
# 𝑇
# (
# 0
# )
# T(0) is known to be 5 (from the initial condition), so we substitute:
#
# 𝑇
# (
# 1
# )
# =
# 3
# ×
# 5
# +
# 12
# ×
# 1
# T(1)=3×5+12×1
# Now, perform the multiplication:
#
# 𝑇
# (
# 1
# )
# =
# 15
# +
# 12
# =
# 27
# T(1)=15+12=27
# So,
# 𝑇
# (
# 1
# )
# T(1) is 27.
#
# Step 2: Calculate
# 𝑇
# (
# 2
# )
# T(2)
# Next, to find
# 𝑇
# (
# 2
# )
# T(2), use the recurrence relation with
# 𝑛
# =
# 2
# n=2:
#
# 𝑇
# (
# 2
# )
# =
# 3
# 𝑇
# (
# 1
# )
# +
# 12
# ×
# 2
# T(2)=3T(1)+12×2
# We already calculated
# 𝑇
# (
# 1
# )
# =
# 27
# T(1)=27, so substitute that value in:
#
# 𝑇
# (
# 2
# )
# =
# 3
# ×
# 27
# +
# 12
# ×
# 2
# T(2)=3×27+12×2
# Perform the multiplication:
#
# 𝑇
# (
# 2
# )
# =
# 81
# +
# 24
# =
# 105
# T(2)=81+24=105

# %% [markdown]
# ## 2. Given a recurrence relation, solve it using the substitution method:
# ## a. T(n) = T(n-1) + c

# %% [markdown]
# The recurrence relation
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 𝑐
# T(n)=T(n−1)+c is a common form where
# 𝑐
# c is a constant. Let's explore this recurrence relation and solve it to find a general formula for
# 𝑇
# (
# 𝑛
# )
# T(n).
#
# Understanding the Recurrence Relation
# Given Relation:
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 𝑐
# T(n)=T(n−1)+c
# Initial Condition: Let's assume
# 𝑇
# (
# 0
# )
# =
# 𝑇
# 0
# T(0)=T
# 0
# ​
#  , where
# 𝑇
# 0
# T
# 0
# ​
#   is some constant initial value.
# This relation suggests that each value of
# 𝑇
# (
# 𝑛
# )
# T(n) is obtained by adding a constant
# 𝑐
# c to the previous value
# 𝑇
# (
# 𝑛
# −
# 1
# )
# T(n−1).
#
# Step-by-Step Calculation for Small Values of
# 𝑛
# n
# Let's manually compute the first few values to see the pattern:
#
# 𝑇
# (
# 0
# )
# =
# 𝑇
# 0
# T(0)=T
# 0
# ​
#   (given as the initial condition)
# 𝑇
# (
# 1
# )
# =
# 𝑇
# (
# 0
# )
# +
# 𝑐
# =
# 𝑇
# 0
# +
# 𝑐
# T(1)=T(0)+c=T
# 0
# ​
#  +c
# 𝑇
# (
# 2
# )
# =
# 𝑇
# (
# 1
# )
# +
# 𝑐
# =
# (
# 𝑇
# 0
# +
# 𝑐
# )
# +
# 𝑐
# =
# 𝑇
# 0
# +
# 2
# 𝑐
# T(2)=T(1)+c=(T
# 0
# ​
#  +c)+c=T
# 0
# ​
#  +2c
# 𝑇
# (
# 3
# )
# =
# 𝑇
# (
# 2
# )
# +
# 𝑐
# =
# (
# 𝑇
# 0
# +
# 2
# 𝑐
# )
# +
# 𝑐
# =
# 𝑇
# 0
# +
# 3
# 𝑐
# T(3)=T(2)+c=(T
# 0
# ​
#  +2c)+c=T
# 0
# ​
#  +3c
# And so on...
# General Formula for
# 𝑇
# (
# 𝑛
# )
# T(n)
# Based on the pattern, we can generalize the formula for
# 𝑇
# (
# 𝑛
# )
# T(n):
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# 0
# +
# 𝑛
# ×
# 𝑐
# T(n)=T
# 0
# ​
#  +n×c
# This formula tells us that the value of
# 𝑇
# (
# 𝑛
# )
# T(n) is the initial value
# 𝑇
# 0
# T
# 0
# ​
#   plus
# 𝑛
# n times the constant
# 𝑐
# c.

# %% [markdown]
# ## b. T(n) = 2T(n/2) + n

# %% [markdown]
# We'll solve this using the Master Theorem, which is commonly used for recurrences of this form:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑎
# 𝑇
# (
# 𝑛
# 𝑏
# )
# +
# 𝑓
# (
# 𝑛
# )
# T(n)=aT(
# b
# n
# ​
#  )+f(n)
# For this recurrence:
#
# 𝑎
# =
# 2
# a=2 (since we have
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# 2T(n/2))
# 𝑏
# =
# 2
# b=2 (because the problem size is divided by 2 in each step)
# 𝑓
# (
# 𝑛
# )
# =
# 𝑛
# f(n)=n (the additional work done outside the recursive calls)
# The Master Theorem states that:
#
# 𝑇
# (
# 𝑛
# )
# =
# {
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# )
# if
# 𝑓
# (
# 𝑛
# )
# =
# 𝑂
# (
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# −
# 𝜖
# )
#  for some
# 𝜖
# >
# 0
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# log
# ⁡
# 𝑛
# )
# if
# 𝑓
# (
# 𝑛
# )
# =
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# )
# Θ
# (
# 𝑓
# (
# 𝑛
# )
# )
# if
# 𝑓
# (
# 𝑛
# )
# =
# Ω
# (
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# +
# 𝜖
# )
#  for some
# 𝜖
# >
# 0
# ,
#  and if
# 𝑎
# 𝑓
# (
# 𝑛
# 𝑏
# )
# ≤
# 𝑐
# 𝑓
# (
# 𝑛
# )
#  for some
# 𝑐
# <
# 1
# T(n)=
# ⎩
# ⎨
# ⎧
# ​
#
# Θ(n
# log
# b
# ​
#  a
#  )
# Θ(n
# log
# b
# ​
#  a
#  logn)
# Θ(f(n))
# ​
#
# if f(n)=O(n
# log
# b
# ​
#  a−ϵ
#  ) for some ϵ>0
# if f(n)=Θ(n
# log
# b
# ​
#  a
#  )
# if f(n)=Ω(n
# log
# b
# ​
#  a+ϵ
#  ) for some ϵ>0, and if af(
# b
# n
# ​
#  )≤cf(n) for some c<1
# ​
#
# Applying the Master Theorem
# Let's apply it step by step.
#
# Calculate
# log
# ⁡
# 𝑏
# 𝑎
# log
# b
# ​
#  a:
#
# log
# ⁡
# 𝑏
# 𝑎
# =
# log
# ⁡
# 2
# 2
# =
# 1
# log
# b
# ​
#  a=log
# 2
# ​
#  2=1
# Compare
# 𝑓
# (
# 𝑛
# )
# f(n) to
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# =
# 𝑛
# 1
# =
# 𝑛
# n
# log
# b
# ​
#  a
#  =n
# 1
#  =n:
#
# Here,
# 𝑓
# (
# 𝑛
# )
# =
# 𝑛
# f(n)=n, which is
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# )
# =
# Θ
# (
# 𝑛
# )
# Θ(n
# log
# b
# ​
#  a
#  )=Θ(n).
# Since
# 𝑓
# (
# 𝑛
# )
# =
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# )
# f(n)=Θ(n
# log
# b
# ​
#  a
#  ), we fall into the second case of the Master Theorem.
#
# Result
# The solution to the recurrence relation is:
#
# 𝑇
# (
# 𝑛
# )
# =
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑛
# )
# T(n)=Θ(nlogn)

# %% [markdown]
# ## c. T(n) = 2T(n/2) + c

# %% [markdown]
# The general form of a recurrence relation for the Master Theorem is:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑎
# 𝑇
# (
# 𝑛
# 𝑏
# )
# +
# 𝑓
# (
# 𝑛
# )
# T(n)=aT(
# b
# n
# ​
#  )+f(n)
# For this specific recurrence:
#
# 𝑎
# =
# 2
# a=2 (since we have
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# 2T(n/2))
# 𝑏
# =
# 2
# b=2 (because the problem size is divided by 2 in each step)
# 𝑓
# (
# 𝑛
# )
# =
# 𝑐
# f(n)=c (the constant work done outside the recursive calls)
# Step 1: Calculate
# log
# ⁡
# 𝑏
# 𝑎
# log
# b
# ​
#  a
# log
# ⁡
# 𝑏
# 𝑎
# =
# log
# ⁡
# 2
# 2
# =
# 1
# log
# b
# ​
#  a=log
# 2
# ​
#  2=1
# Step 2: Compare
# 𝑓
# (
# 𝑛
# )
# f(n) to
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# =
# 𝑛
# 1
# =
# 𝑛
# n
# log
# b
# ​
#  a
#  =n
# 1
#  =n
# Here,
# 𝑓
# (
# 𝑛
# )
# =
# 𝑐
# f(n)=c, which is a constant.
# A constant function
# 𝑓
# (
# 𝑛
# )
# =
# 𝑐
# =
# Θ
# (
# 𝑛
# 0
# )
# f(n)=c=Θ(n
# 0
#  ).
# Step 3: Apply the Master Theorem
# Now, compare the growth of
# 𝑓
# (
# 𝑛
# )
# f(n) with
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# =
# 𝑛
# n
# log
# b
# ​
#  a
#  =n:
#
# Since
# 𝑛
# 0
# =
# 1
# n
# 0
#  =1 and
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# =
# 𝑛
# n
# log
# b
# ​
#  a
#  =n, we see that
# 𝑓
# (
# 𝑛
# )
# =
# 𝑐
# f(n)=c grows slower than
# 𝑛
# n (i.e.,
# 𝑓
# (
# 𝑛
# )
# =
# 𝑂
# (
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# −
# 𝜖
# )
# f(n)=O(n
# log
# b
# ​
#  a−ϵ
#  ) for
# 𝜖
# =
# 1
# ϵ=1).
# This means we are in the first case of the Master Theorem, where:
#
# 𝑇
# (
# 𝑛
# )
# =
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# )
# =
# Θ
# (
# 𝑛
# 1
# )
# =
# Θ
# (
# 𝑛
# )
# T(n)=Θ(n
# log
# b
# ​
#  a
#  )=Θ(n
# 1
#  )=Θ(n)
# Intuition Behind the Solution
# The problem size is divided into two subproblems of size
# 𝑛
# /
# 2
# n/2, and
# 𝑐
# c constant work is added for each level of recursion.
# Even though the constant
# 𝑐
# c does not change with
# 𝑛
# n, the total work accumulates linearly because the depth of the recursion tree is logarithmic in
# 𝑛
# n, and each level of the tree involves linear work when summed over all levels.

# %% [markdown]
# ## d. T(n) = T(n/2) + c

# %% [markdown]
# The recurrence relation
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=T(n/2)+c, where
# 𝑐
# c is a constant, can be solved to find the asymptotic behavior of
# 𝑇
# (
# 𝑛
# )
# T(n). This type of recurrence is common in analyzing the time complexity of algorithms that divide a problem in half at each step, with a constant amount of additional work.
#
# Analyzing the Recurrence
# This recurrence suggests that at each step, the problem size is reduced by half, and a constant
# 𝑐
# c amount of work is done. Let's solve this using a method known as recursion tree analysis or by applying the Master Theorem.
#
# 1. Recursion Tree Analysis
# To understand the pattern, let's manually expand the recurrence:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=T(n/2)+c
# If we expand this recursively, we get:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=T(n/2)+c
# 𝑇
# (
# 𝑛
# /
# 2
# )
# =
# 𝑇
# (
# 𝑛
# /
# 4
# )
# +
# 𝑐
# T(n/2)=T(n/4)+c
# 𝑇
# (
# 𝑛
# /
# 4
# )
# =
# 𝑇
# (
# 𝑛
# /
# 8
# )
# +
# 𝑐
# T(n/4)=T(n/8)+c
# And so on...
# And so on...
# At each level of recursion, we subtract a constant
# 𝑐
# c, and the problem size reduces by a factor of 2 each time. Eventually, the problem size reduces to
# 𝑇
# (
# 1
# )
# T(1), which we assume is a base case
# 𝑇
# (
# 1
# )
# =
# 𝑇
# 0
# T(1)=T
# 0
# ​
#  .
#
# So, after
# 𝑘
# k levels, where
# 𝑛
# /
# 2
# 𝑘
# =
# 1
# n/2
# k
#  =1, we have:
#
# 𝑛
# =
# 2
# 𝑘
# or
# 𝑘
# =
# log
# ⁡
# 2
# 𝑛
# n=2
# k
#  ork=log
# 2
# ​
#  n
# The total work done is the sum of the constant work
# 𝑐
# c at each level, over
# log
# ⁡
# 2
# 𝑛
# log
# 2
# ​
#  n levels:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 1
# )
# +
# 𝑐
# ⋅
# log
# ⁡
# 2
# 𝑛
# T(n)=T(1)+c⋅log
# 2
# ​
#  n
# Since
# 𝑇
# (
# 1
# )
# T(1) is a constant, say
# 𝑇
# 0
# T
# 0
# ​
#  , we can write:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# 0
# +
# 𝑐
# ⋅
# log
# ⁡
# 2
# 𝑛
# T(n)=T
# 0
# ​
#  +c⋅log
# 2
# ​
#  n
# For large
# 𝑛
# n, the constant
# 𝑇
# 0
# T
# 0
# ​
#   becomes negligible, so:
#
# 𝑇
# (
# 𝑛
# )
# =
# Θ
# (
# log
# ⁡
# 𝑛
# )
# T(n)=Θ(logn)
# 2. Master Theorem Application
# Alternatively, we can apply the Master Theorem to verify this result. The Master Theorem is applied to recurrences of the form:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑎
# 𝑇
# (
# 𝑛
# 𝑏
# )
# +
# 𝑓
# (
# 𝑛
# )
# T(n)=aT(
# b
# n
# ​
#  )+f(n)
# For
# 𝑇
# (
# 𝑛
# )
# =
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑐
# T(n)=T(n/2)+c:
#
# 𝑎
# =
# 1
# a=1
# 𝑏
# =
# 2
# b=2
# 𝑓
# (
# 𝑛
# )
# =
# 𝑐
# =
# Θ
# (
# 1
# )
# f(n)=c=Θ(1) (constant function)
# We compute
# log
# ⁡
# 𝑏
# 𝑎
# log
# b
# ​
#  a:
#
# log
# ⁡
# 𝑏
# 𝑎
# =
# log
# ⁡
# 2
# 1
# =
# 0
# log
# b
# ​
#  a=log
# 2
# ​
#  1=0
# Now, we compare
# 𝑓
# (
# 𝑛
# )
# f(n) with
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# =
# 𝑛
# 0
# =
# 1
# n
# log
# b
# ​
#  a
#  =n
# 0
#  =1:
#
# 𝑓
# (
# 𝑛
# )
# =
# Θ
# (
# 1
# )
# =
# Θ
# (
# 𝑛
# 0
# )
# f(n)=Θ(1)=Θ(n
# 0
#  )
# This falls into the second case of the Master Theorem, where
# 𝑓
# (
# 𝑛
# )
# =
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑏
# 𝑎
# log
# ⁡
# 𝑛
# )
# f(n)=Θ(n
# log
# b
# ​
#  a
#  logn):
#
# 𝑇
# (
# 𝑛
# )
# =
# Θ
# (
# log
# ⁡
# 𝑛
# )
# T(n)=Θ(logn)

# %% [markdown]
# ## 3. Given a recurrence relation, solve it using the recursive tree approach:
# a. T(n) = 2T(n-1) +1

# %% [markdown]
# Step 1: Expand the Recurrence
# Let's expand the recurrence step by step:
#
# First expansion:
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 1
# T(n)=2T(n−1)+1
# Substitute
# 𝑇
# (
# 𝑛
# −
# 1
# )
# T(n−1) using the same recurrence:
# 𝑇
# (
# 𝑛
# )
# =
# 2
# [
# 2
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 1
# ]
# +
# 1
# =
# 2
# 2
# 𝑇
# (
# 𝑛
# −
# 2
# )
# +
# 2
# +
# 1
# T(n)=2[2T(n−2)+1]+1=2
# 2
#  T(n−2)+2+1
# Substitute
# 𝑇
# (
# 𝑛
# −
# 2
# )
# T(n−2) using the recurrence:
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 2
# [
# 2
# 𝑇
# (
# 𝑛
# −
# 3
# )
# +
# 1
# ]
# +
# 2
# +
# 1
# =
# 2
# 3
# 𝑇
# (
# 𝑛
# −
# 3
# )
# +
# 2
# 2
# +
# 2
# +
# 1
# T(n)=2
# 2
#  [2T(n−3)+1]+2+1=2
# 3
#  T(n−3)+2
# 2
#  +2+1
# General pattern:
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑘
# 𝑇
# (
# 𝑛
# −
# 𝑘
# )
# +
# 2
# 𝑘
# −
# 1
# +
# 2
# 𝑘
# −
# 2
# +
# ⋯
# +
# 2
# +
# 1
# T(n)=2
# k
#  T(n−k)+2
# k−1
#  +2
# k−2
#  +⋯+2+1
# Step 2: Determine the Number of Levels
# The expansion continues until
# 𝑛
# −
# 𝑘
# =
# 0
# n−k=0, which occurs when
# 𝑘
# =
# 𝑛
# k=n. So, the recursion will terminate when
# 𝑘
# =
# 𝑛
# k=n, leading to
# 𝑇
# (
# 0
# )
# T(0).
#
# Step 3: Sum the Contributions at Each Level
# When
# 𝑘
# =
# 𝑛
# k=n, the expression becomes:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑛
# 𝑇
# (
# 0
# )
# +
# (
# 2
# 𝑛
# −
# 1
# +
# 2
# 𝑛
# −
# 2
# +
# ⋯
# +
# 2
# +
# 1
# )
# T(n)=2
# n
#  T(0)+(2
# n−1
#  +2
# n−2
#  +⋯+2+1)
# Assuming
# 𝑇
# (
# 0
# )
# T(0) is a constant (let's call it
# 𝑇
# 0
# T
# 0
# ​
#  ):
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑛
# 𝑇
# 0
# +
# ∑
# 𝑖
# =
# 0
# 𝑛
# −
# 1
# 2
# 𝑖
# T(n)=2
# n
#  T
# 0
# ​
#  +
# i=0
# ∑
# n−1
# ​
#  2
# i
#
# Step 4: Sum the Geometric Series
# The sum
# ∑
# 𝑖
# =
# 0
# 𝑛
# −
# 1
# 2
# 𝑖
# ∑
# i=0
# n−1
# ​
#  2
# i
#   is a geometric series:
#
# ∑
# 𝑖
# =
# 0
# 𝑛
# −
# 1
# 2
# 𝑖
# =
# 2
# 𝑛
# −
# 1
# 2
# −
# 1
# =
# 2
# 𝑛
# −
# 1
# i=0
# ∑
# n−1
# ​
#  2
# i
#  =
# 2−1
# 2
# n
#  −1
# ​
#  =2
# n
#  −1
# Therefore, the recurrence simplifies to:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑛
# 𝑇
# 0
# +
# (
# 2
# 𝑛
# −
# 1
# )
# T(n)=2
# n
#  T
# 0
# ​
#  +(2
# n
#  −1)
# Simplifying further:
#
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑛
# (
# 𝑇
# 0
# +
# 1
# )
# −
# 1
# T(n)=2
# n
#  (T
# 0
# ​
#  +1)−1
# Step 5: Asymptotic Behavior
# For large
# 𝑛
# n, the term
# 2
# 𝑛
# (
# 𝑇
# 0
# +
# 1
# )
# −
# 1
# 2
# n
#  (T
# 0
# ​
#  +1)−1 dominates, so we can express the solution asymptotically as:
#
# 𝑇
# (
# 𝑛
# )
# =
# Θ
# (
# 2
# 𝑛
# )
# T(n)=Θ(2
# n
#  )

# %% [markdown]
# ## b. T(n) = 2T(n/2) + n

# %% [markdown]
# Step 1: Draw the Recursion Tree
# The recurrence
# 𝑇
# (
# 𝑛
# )
# =
# 2
# 𝑇
# (
# 𝑛
# /
# 2
# )
# +
# 𝑛
# T(n)=2T(n/2)+n indicates that the problem of size
# 𝑛
# n is divided into two subproblems of size
# 𝑛
# /
# 2
# n/2, each contributing to the total work. The additional
# 𝑛
# n term represents the work done at the current level.
#
# We can visualize the recursion tree as follows:
#
# Level 0 (root, size
# 𝑛
# n):
#
# The total work is
# 𝑛
# n.
# Two recursive calls to
# 𝑇
# (
# 𝑛
# /
# 2
# )
# T(n/2).
# Level 1 (size
# 𝑛
# /
# 2
# n/2):
#
# Each subproblem of size
# 𝑛
# /
# 2
# n/2 contributes
# 𝑛
# /
# 2
# n/2 work.
# There are two subproblems, so the total work at this level is
# 2
# ×
# 𝑛
# 2
# =
# 𝑛
# 2×
# 2
# n
# ​
#  =n.
# Each subproblem again divides into two subproblems of size
# 𝑛
# /
# 4
# n/4.
# Level 2 (size
# 𝑛
# /
# 4
# n/4):
#
# Each subproblem of size
# 𝑛
# /
# 4
# n/4 contributes
# 𝑛
# /
# 4
# n/4 work.
# There are four subproblems, so the total work at this level is
# 4
# ×
# 𝑛
# 4
# =
# 𝑛
# 4×
# 4
# n
# ​
#  =n.
# This pattern continues...
# Step 2: Summing the Work Across All Levels
# The key observation here is that at each level of the recursion tree, the total work done is
# 𝑛
# n. The number of levels in the tree corresponds to the depth of the recursion, which can be calculated as follows:
#
# The problem size reduces from
# 𝑛
# n to
# 𝑛
# /
# 2
# n/2 to
# 𝑛
# /
# 4
# n/4, and so on, until we reach the base case
# 𝑇
# (
# 1
# )
# T(1).
# This means the depth of the tree is
# log
# ⁡
# 2
# 𝑛
# log
# 2
# ​
#  n.
# Now, sum up the work done at each level:
#
# Level 0:
# 𝑛
# n
# Level 1:
# 𝑛
# n
# Level 2:
# 𝑛
# n
# ...
# Level
# log
# ⁡
# 2
# 𝑛
# log
# 2
# ​
#  n:
# 𝑛
# n
# Since there are
# log
# ⁡
# 2
# 𝑛
# +
# 1
# log
# 2
# ​
#  n+1 levels, the total work is:
#
# 𝑇
# (
# 𝑛
# )
# =
# 𝑛
# +
# 𝑛
# +
# 𝑛
# +
# ⋯
# +
# 𝑛
#
# (
# log
# ⁡
# 2
# 𝑛
# +
# 1
#  times
# )
# T(n)=n+n+n+⋯+n (log
# 2
# ​
#  n+1 times)
# 𝑇
# (
# 𝑛
# )
# =
# 𝑛
# ×
# (
# log
# ⁡
# 2
# 𝑛
# +
# 1
# )
# T(n)=n×(log
# 2
# ​
#  n+1)
# Step 3: Asymptotic Analysis
# For large
# 𝑛
# n, the constant
# +
# 1
# +1 can be ignored, so:
#
# 𝑇
# (
# 𝑛
# )
# =
# Θ
# (
# 𝑛
# log
# ⁡
# 𝑛
# )
# T(n)=Θ(nlogn)
